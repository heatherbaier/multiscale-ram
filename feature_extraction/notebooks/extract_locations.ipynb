# %%
import os
import time
import shutil
import pickle

import torch
import torch.nn.functional as F

from tqdm import tqdm
from torch.optim.lr_scheduler import ReduceLROnPlateau
# from tensorboard_logger import configure, log_value

from model import RecurrentAttention
from utils import AverageMeter

from torchvision import transforms, utils, models
from PIL import Image

import torch

import utils

from trainer import Trainer
from config import get_config

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

import pandas as pd

import json

# %%
def load_inputs(impath):
    to_tens = transforms.ToTensor()
    return to_tens(Image.open(impath).convert('RGB')).unsqueeze(0)

# %%
m = open("../../pooling/data/migration_data.json",)
mig_data = json.load(m)
m.close()
mig_data = pd.DataFrame.from_dict(mig_data, orient = 'index').reset_index()
mig_data.columns = ['muni_id', 'num_migrants']
q = 4
mig_data['class'] = pd.qcut(mig_data['num_migrants'], q = q, labels = [i for i in range(q)])
mig_data
# Out:
#         muni_id  num_migrants class
# 0     484001001       42055.0     3
# 1     484001002        4017.0     3
# 2     484001003       11992.0     3
# 3     484001004         762.0     2
# 4     484001005        7551.0     3
# ...         ...           ...   ...
# 2326  484032049        2487.0     3
# 2327  484032050        2024.0     3
# 2328  484032051        3084.0     3
# 2329  484032052        2919.0     3
# 2330  484032053        2119.0     3
#
# [2331 rows x 3 columns]

# %%
mig_data['class'].value_counts()
# Out:
# 0    583
# 1    583
# 2    583
# 3    582
# Name: class, dtype: int64

# %%
def get_png_names(directory):
    images = []
    for i in os.listdir(directory):
        try:
            if os.path.isdir(os.path.join(directory, i)):
                new_path = os.path.join(directory, i, "pngs")
                image = os.listdir(new_path)[0]
                images.append(os.path.join(directory, i, "pngs", image))
        except:
            pass
    return images


            

image_names = get_png_names("../../attn/data/MEX/")

y_class, y_mig = [], []

for i in image_names:
        dta = mig_data[mig_data["muni_id"] == i.split("/")[5]]
        if len(dta) != 0:
            y_class.append(dta['class'].values[0])
            y_mig.append(dta['num_migrants'].values[0])

# %%
import matplotlib.pyplot as plt
import torchvision

# %%
import random

train_num = int(25 * .70)

train_indices = random.sample(range(0, 25), train_num)
val_indices = [i for i in range(0, 25) if i not in train_indices]

# %%
import torchvision

batch_size = 1

# train = [(load_inputs(image_paths[i]).squeeze()[:, 0:28, 0:28], ys[i]) for i in range(0, 93)]
# val = [(load_inputs(image_paths[i]).squeeze()[:, 0:28, 0:28], ys[i]) for i in range(93, 133)]

# brighten = torchvision.transforms.functional.adjust_brightness(brightness_factor = 2)


train = [(torchvision.transforms.functional.adjust_brightness(load_inputs(image_names[i]), brightness_factor = 2).squeeze(), y_class[i], y_mig[i]) for i in train_indices]
val = [(torchvision.transforms.functional.adjust_brightness(load_inputs(image_names[i]), brightness_factor = 2).squeeze(), y_class[i], y_mig[i]) for i in val_indices]


train_dl = torch.utils.data.DataLoader(train, batch_size = batch_size, shuffle = True)
val_dl = torch.utils.data.DataLoader(val, batch_size = batch_size, shuffle = True)

# %%
print("Num training: ", len(train_dl))
print("Num validation: ", len(val_dl))
# Out:
# Num training:  17
# Num validation:  8

# %%
import numpy as np
from utils import plot_images

import torch
from torchvision import datasets
from torchvision import transforms
from torch.utils.data.sampler import SubsetRandomSampler

# %%
config, unparsed = get_config()

# %%
trainer = Trainer(config, (train_dl, val_dl))

# %%
checkpoint = torch.load("./ckpt/ram_4_50x50_0.75_model_best.pth.tar")
checkpoint = checkpoint["model_state"]

# %%
import pickle
import argparse
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from utils import denormalize, bounding_box

def denormalize(T, coords):
    return 0.5 * ((coords + 1.0) * T)

# %%
def exceeds(from_x, to_x, from_y, to_y, H, W):
    """Check whether the extracted patch will exceed
    the boundaries of the image of size `T`.
    """
    if (from_x < 0) or (from_y < 0) or (to_x > H) or (to_y > W):
        return True
    return False


def fix(from_x, to_x, from_y, to_y, H, W, size):

    """
    Check whether the extracted patch will exceed
    the boundaries of the image of size `T`.
    If it will exceed, make a list of the offending reasons and fix them
    """

    offenders = []

    if (from_x < 0):
        offenders.append("negative x")
    if from_y < 0:
        offenders.append("negative y")
    if from_x > H:
        offenders.append("from_x exceeds h")            
    if to_x > H:
        offenders.append("to_x exceeds h")
    if from_y > W:
        offenders.append("from_y exceeds w")
    if to_y > W:
        offenders.append("to_y exceeds w")            


    if ("from_y exceeds w" in offenders) or ("to_y exceeds w" in offenders):
        from_y, to_y = W - size, W

    if ("from_x exceeds h" in offenders) or ("to_x exceeds h" in offenders):
        from_x, to_x = H - size, H     

    elif ("negative x" in offenders):
        from_x, to_x = 0, 0 + size

    elif ("negative y" in offenders):
        from_y, to_y = 0, 0 + size            

    return from_x, to_x, from_y, to_y

# %%
locations_dict = {}
scales = 2
scale_factor = .75

for i in image_names[0:25]:
    
    print(i)
    
    muni_id = i.split("/")[5]
    image = load_inputs(i)
    locations = trainer.extract_locations(image, checkpoint)
    
    start = [denormalize(image.shape[2], l) for l in locations]
    start = torch.cat([start[l].unsqueeze(0) for l in range(4)])
        
    B, C, H, W = image.shape
    
    og_size = int(min(H, W) / 5)
    
    size = int(min(H, W) / 5)
    
    coords_dict = {}
    
    for scale in range(0, scales):
            
        end = start + size

        for c in range(0, len(start)):

            from_coords = start[c]
            to_coords = end[c]

            from_x = from_coords[0][0].item()
            from_y = from_coords[0][1].item()

            to_x = to_coords[0][0].item()
            to_y = to_coords[0][1] .item()   

            if exceeds(from_x = from_x, to_x = to_x, from_y = from_y, to_y = to_y, H = H, W = W):

                from_x, to_x, from_y, to_y = fix(from_x = from_x, to_x = to_x, from_y = from_y, to_y = to_y, H = H, W = W, size = size)

                print("yes")

            coords_dict['glimpse' + str(c) + "_scale" + str(scale)] = {'from_x': from_x, 'to_x': to_x, 'from_y': from_y, 'to_y': to_y}
    
        size = size * scale_factor
    
    
    
    locations_dict[i] = coords_dict
# Out:
# ../../attn/data/MEX/484001008/pngs/484001008_2010_all_box484001008_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484004004/pngs/484004004_2010_all_box484004004_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484004001/pngs/484004001_2010_all_box484004001_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484005010/pngs/484005010_2010_all_box484005010_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484001005/pngs/484001005_2010_all_box484001005_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484001007/pngs/484001007_2010_all_box484001007_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484001006/pngs/484001006_2010_all_box484001006_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484001001/pngs/484001001_2010_all_box484001001_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484004005/pngs/484004005_2010_all_box484004005_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484005001/pngs/484005001_2010_all_box484005001_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484005004/pngs/484005004_2010_all_box484005004_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484005008/pngs/484005008_2010_all_box484005008_MAY.png
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484001002/pngs/484001002_2010_all_box484001002_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484004006/pngs/484004006_2010_all_box484004006_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484001004/pngs/484001004_2010_all_box484001004_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484005013/pngs/484005013_2010_all_box484005013_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484001003/pngs/484001003_2010_all_box484001003_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484005003/pngs/484005003_2010_all_box484005003_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484005018/pngs/484005018_2010_all_box484005018_MAY.png
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484005019/pngs/484005019_2010_all_box484005019_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484005016/pngs/484005016_2010_all_box484005016_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484005015/pngs/484005015_2010_all_box484005015_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484005014/pngs/484005014_2010_all_box484005014_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484005017/pngs/484005017_2010_all_box484005017_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ../../attn/data/MEX/484005021/pngs/484005021_2010_all_box484005021_MAY.png
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes

# %%
locations_dict
# Out:
# {'../../attn/data/MEX/484001008/pngs/484001008_2010_all_box484001008_MAY.png': {'glimpse0_scale0': {'from_x': 767,
#    'to_x': 881,
#    'from_y': 435.4316101074219,
#    'to_y': 549.431640625},
#   'glimpse1_scale0': {'from_x': 767, 'to_x': 881, 'from_y': 456, 'to_y': 570},
#   'glimpse2_scale0': {'from_x': 494.0845642089844,
#    'to_x': 608.0845947265625,
#    'from_y': 456,
#    'to_y': 570},
#   'glimpse3_scale0': {'from_x': 645.1622314453125,
#    'to_x': 759.1622314453125,
#    'from_y': 456,
#    'to_y': 570},
#   'glimpse0_scale1': {'from_x': 795.5,
#    'to_x': 881,
#    'from_y': 435.4316101074219,
#    'to_y': 520.931640625},
#   'glimpse1_scale1': {'from_x': 795.5,
#    'to_x': 881,
#    'from_y': 484.5,
#    'to_y': 570},
#   'glimpse2_scale1': {'from_x': 494.0845642089844,
#    'to_x': 579.5845947265625,
#    'from_y': 484.5,
#    'to_y': 570},
#   'glimpse3_scale1': {'from_x': 645.1622314453125,
#    'to_x': 730.6622314453125,
#    'from_y': 484.5,
#    'to_y': 570}},
#  '../../attn/data/MEX/484004004/pngs/484004004_2010_all_box484004004_MAY.png': {'glimpse0_scale0': {'from_x': 1056,
#    'to_x': 1320,
#    'from_y': 1320.0,
#    'to_y': 1584.0},
#   'glimpse1_scale0': {'from_x': 1056,
#    'to_x': 1320,
#    'from_y': 1271.997802734375,
#    'to_y': 1535.997802734375},
#   'glimpse2_scale0': {'from_x': 1056,
#    'to_x': 1320,
#    'from_y': 1224.7322998046875,
#    'to_y': 1488.7322998046875},
#   'glimpse3_scale0': {'from_x': 938.587158203125,
#    'to_x': 1202.587158203125,
#    'from_y': 1215.03466796875,
#    'to_y': 1479.03466796875},
#   'glimpse0_scale1': {'from_x': 1122.0,
#    'to_x': 1320,
#    'from_y': 1320.0,
#    'to_y': 1518.0},
#   'glimpse1_scale1': {'from_x': 1122.0,
#    'to_x': 1320,
#    'from_y': 1271.997802734375,
#    'to_y': 1469.997802734375},
#   'glimpse2_scale1': {'from_x': 1122.0,
#    'to_x': 1320,
#    'from_y': 1224.7322998046875,
#    'to_y': 1422.7322998046875},
#   'glimpse3_scale1': {'from_x': 938.587158203125,
#    'to_x': 1136.587158203125,
#    'from_y': 1215.03466796875,
#    'to_y': 1413.03466796875}},
#  '../../attn/data/MEX/484004001/pngs/484004001_2010_all_box484004001_MAY.png': {'glimpse0_scale0': {'from_x': 2243,
#    'to_x': 2732,
#    'from_y': 1959,
#    'to_y': 2448},
#   'glimpse1_scale0': {'from_x': 2243,
#    'to_x': 2732,
#    'from_y': 1959,
#    'to_y': 2448},
#   'glimpse2_scale0': {'from_x': 2243,
#    'to_x': 2732,
#    'from_y': 1959,
#    'to_y': 2448},
#   'glimpse3_scale0': {'from_x': 2243,
#    'to_x': 2732,
#    'from_y': 1959,
#    'to_y': 2448},
#   'glimpse0_scale1': {'from_x': 2365.25,
#    'to_x': 2732,
#    'from_y': 2081.25,
#    'to_y': 2448},
#   'glimpse1_scale1': {'from_x': 2365.25,
#    'to_x': 2732,
#    'from_y': 2081.25,
#    'to_y': 2448},
#   'glimpse2_scale1': {'from_x': 2365.25,
#    'to_x': 2732,
#    'from_y': 2081.25,
#    'to_y': 2448},
#   'glimpse3_scale1': {'from_x': 2365.25,
#    'to_x': 2732,
#    'from_y': 2081.25,
#    'to_y': 2448}},
#  '../../attn/data/MEX/484005010/pngs/484005010_2010_all_box484005010_MAY.png': {'glimpse0_scale0': {'from_x': 874,
#    'to_x': 1092,
#    'from_y': 881.2607421875,
#    'to_y': 1099.2607421875},
#   'glimpse1_scale0': {'from_x': 474.06158447265625,
#    'to_x': 692.0615844726562,
#    'from_y': 1092.0,
#    'to_y': 1310.0},
#   'glimpse2_scale0': {'from_x': 874,
#    'to_x': 1092,
#    'from_y': 822.0250854492188,
#    'to_y': 1040.025146484375},
#   'glimpse3_scale0': {'from_x': 874,
#    'to_x': 1092,
#    'from_y': 1092.0,
#    'to_y': 1310.0},
#   'glimpse0_scale1': {'from_x': 928.5,
#    'to_x': 1092,
#    'from_y': 881.2607421875,
#    'to_y': 1044.7607421875},
#   'glimpse1_scale1': {'from_x': 474.06158447265625,
#    'to_x': 637.5615844726562,
#    'from_y': 1092.0,
#    'to_y': 1255.5},
#   'glimpse2_scale1': {'from_x': 928.5,
#    'to_x': 1092,
#    'from_y': 822.0250854492188,
#    'to_y': 985.5250854492188},
#   'glimpse3_scale1': {'from_x': 928.5,
#    'to_x': 1092,
#    'from_y': 1092.0,
#    'to_y': 1255.5}},
#  '../../attn/data/MEX/484001005/pngs/484001005_2010_all_box484001005_MAY.png': {'glimpse0_scale0': {'from_x': 685.7525024414062,
#    'to_x': 875.7525024414062,
#    'from_y': 916.41552734375,
#    'to_y': 1106.41552734375},
#   'glimpse1_scale0': {'from_x': 763,
#    'to_x': 953,
#    'from_y': 953.0,
#    'to_y': 1143.0},
#   'glimpse2_scale0': {'from_x': 763,
#    'to_x': 953,
#    'from_y': 953.0,
#    'to_y': 1143.0},
#   'glimpse3_scale0': {'from_x': 763,
#    'to_x': 953,
#    'from_y': 750.394287109375,
#    'to_y': 940.394287109375},
#   'glimpse0_scale1': {'from_x': 685.7525024414062,
#    'to_x': 828.2525024414062,
#    'from_y': 916.41552734375,
#    'to_y': 1058.91552734375},
#   'glimpse1_scale1': {'from_x': 810.5,
#    'to_x': 953,
#    'from_y': 953.0,
#    'to_y': 1095.5},
#   'glimpse2_scale1': {'from_x': 810.5,
#    'to_x': 953,
#    'from_y': 953.0,
#    'to_y': 1095.5},
#   'glimpse3_scale1': {'from_x': 810.5,
#    'to_x': 953,
#    'from_y': 750.394287109375,
#    'to_y': 892.894287109375}},
#  '../../attn/data/MEX/484001007/pngs/484001007_2010_all_box484001007_MAY.png': {'glimpse0_scale0': {'from_x': 1089,
#    'to_x': 1341,
#    'from_y': 1009,
#    'to_y': 1261},
#   'glimpse1_scale0': {'from_x': 1089,
#    'to_x': 1341,
#    'from_y': 930.2315673828125,
#    'to_y': 1182.2315673828125},
#   'glimpse2_scale0': {'from_x': 1089,
#    'to_x': 1341,
#    'from_y': 1009,
#    'to_y': 1261},
#   'glimpse3_scale0': {'from_x': 1089,
#    'to_x': 1341,
#    'from_y': 1009,
#    'to_y': 1261},
#   'glimpse0_scale1': {'from_x': 1152.0,
#    'to_x': 1341,
#    'from_y': 1072.0,
#    'to_y': 1261},
#   'glimpse1_scale1': {'from_x': 1152.0,
#    'to_x': 1341,
#    'from_y': 930.2315673828125,
#    'to_y': 1119.2315673828125},
#   'glimpse2_scale1': {'from_x': 1152.0,
#    'to_x': 1341,
#    'from_y': 1072.0,
#    'to_y': 1261},
#   'glimpse3_scale1': {'from_x': 1152.0,
#    'to_x': 1341,
#    'from_y': 1072.0,
#    'to_y': 1261}},
#  '../../attn/data/MEX/484001006/pngs/484001006_2010_all_box484001006_MAY.png': {'glimpse0_scale0': {'from_x': 980.7506713867188,
#    'to_x': 1192.750732421875,
#    'from_y': 851,
#    'to_y': 1063},
#   'glimpse1_scale0': {'from_x': 1080,
#    'to_x': 1292,
#    'from_y': 851,
#    'to_y': 1063},
#   'glimpse2_scale0': {'from_x': 1080,
#    'to_x': 1292,
#    'from_y': 851,
#    'to_y': 1063},
#   'glimpse3_scale0': {'from_x': 1080,
#    'to_x': 1292,
#    'from_y': 851,
#    'to_y': 1063},
#   'glimpse0_scale1': {'from_x': 980.7506713867188,
#    'to_x': 1139.750732421875,
#    'from_y': 904.0,
#    'to_y': 1063},
#   'glimpse1_scale1': {'from_x': 1133.0,
#    'to_x': 1292,
#    'from_y': 904.0,
#    'to_y': 1063},
#   'glimpse2_scale1': {'from_x': 1133.0,
#    'to_x': 1292,
#    'from_y': 904.0,
#    'to_y': 1063},
#   'glimpse3_scale1': {'from_x': 1133.0,
#    'to_x': 1292,
#    'from_y': 904.0,
#    'to_y': 1063}},
#  '../../attn/data/MEX/484001001/pngs/484001001_2010_all_box484001001_MAY.png': {'glimpse0_scale0': {'from_x': 779.68359375,
#    'to_x': 1134.68359375,
#    'from_y': 1029.3399658203125,
#    'to_y': 1384.3399658203125},
#   'glimpse1_scale0': {'from_x': 1422,
#    'to_x': 1777,
#    'from_y': 1777.0,
#    'to_y': 2132.0},
#   'glimpse2_scale0': {'from_x': 1422,
#    'to_x': 1777,
#    'from_y': 1777.0,
#    'to_y': 2132.0},
#   'glimpse3_scale0': {'from_x': 1422,
#    'to_x': 1777,
#    'from_y': 1724.4564208984375,
#    'to_y': 2079.45654296875},
#   'glimpse0_scale1': {'from_x': 779.68359375,
#    'to_x': 1045.93359375,
#    'from_y': 1029.3399658203125,
#    'to_y': 1295.5899658203125},
#   'glimpse1_scale1': {'from_x': 1510.75,
#    'to_x': 1777,
#    'from_y': 1777.0,
#    'to_y': 2043.25},
#   'glimpse2_scale1': {'from_x': 1510.75,
#    'to_x': 1777,
#    'from_y': 1777.0,
#    'to_y': 2043.25},
#   'glimpse3_scale1': {'from_x': 1510.75,
#    'to_x': 1777,
#    'from_y': 1724.4564208984375,
#    'to_y': 1990.7064208984375}},
#  '../../attn/data/MEX/484004005/pngs/484004005_2010_all_box484004005_MAY.png': {'glimpse0_scale0': {'from_x': 2010,
#    'to_x': 2428,
#    'from_y': 1672,
#    'to_y': 2090},
#   'glimpse1_scale0': {'from_x': 2010,
#    'to_x': 2428,
#    'from_y': 1672,
#    'to_y': 2090},
#   'glimpse2_scale0': {'from_x': 1498.2669677734375,
#    'to_x': 1916.2669677734375,
#    'from_y': 1672,
#    'to_y': 2090},
#   'glimpse3_scale0': {'from_x': 2010,
#    'to_x': 2428,
#    'from_y': 1672,
#    'to_y': 2090},
#   'glimpse0_scale1': {'from_x': 2114.5,
#    'to_x': 2428,
#    'from_y': 1776.5,
#    'to_y': 2090},
#   'glimpse1_scale1': {'from_x': 2114.5,
#    'to_x': 2428,
#    'from_y': 1776.5,
#    'to_y': 2090},
#   'glimpse2_scale1': {'from_x': 1498.2669677734375,
#    'to_x': 1811.7669677734375,
#    'from_y': 1776.5,
#    'to_y': 2090},
#   'glimpse3_scale1': {'from_x': 2114.5,
#    'to_x': 2428,
#    'from_y': 1776.5,
#    'to_y': 2090}},
#  '../../attn/data/MEX/484005001/pngs/484005001_2010_all_box484005001_MAY.png': {'glimpse0_scale0': {'from_x': 810,
#    'to_x': 1012,
#    'from_y': 1012.0,
#    'to_y': 1214.0},
#   'glimpse1_scale0': {'from_x': 810,
#    'to_x': 1012,
#    'from_y': 981.7599487304688,
#    'to_y': 1183.760009765625},
#   'glimpse2_scale0': {'from_x': 810,
#    'to_x': 1012,
#    'from_y': 1012.0,
#    'to_y': 1214.0},
#   'glimpse3_scale0': {'from_x': 795.562255859375,
#    'to_x': 997.562255859375,
#    'from_y': 1012.0,
#    'to_y': 1214.0},
#   'glimpse0_scale1': {'from_x': 860.5,
#    'to_x': 1012,
#    'from_y': 1012.0,
#    'to_y': 1163.5},
#   'glimpse1_scale1': {'from_x': 860.5,
#    'to_x': 1012,
#    'from_y': 981.7599487304688,
#    'to_y': 1133.260009765625},
#   'glimpse2_scale1': {'from_x': 860.5,
#    'to_x': 1012,
#    'from_y': 1012.0,
#    'to_y': 1163.5},
#   'glimpse3_scale1': {'from_x': 795.562255859375,
#    'to_x': 947.062255859375,
#    'from_y': 1012.0,
#    'to_y': 1163.5}},
#  '../../attn/data/MEX/484005004/pngs/484005004_2010_all_box484005004_MAY.png': {'glimpse0_scale0': {'from_x': 1139,
#    'to_x': 1423,
#    'from_y': 1305.4378662109375,
#    'to_y': 1589.4378662109375},
#   'glimpse1_scale0': {'from_x': 1139,
#    'to_x': 1423,
#    'from_y': 1423.0,
#    'to_y': 1707.0},
#   'glimpse2_scale0': {'from_x': 1139,
#    'to_x': 1423,
#    'from_y': 1423.0,
#    'to_y': 1707.0},
#   'glimpse3_scale0': {'from_x': 476.4237976074219,
#    'to_x': 760.423828125,
#    'from_y': 1423.0,
#    'to_y': 1707.0},
#   'glimpse0_scale1': {'from_x': 1210.0,
#    'to_x': 1423,
#    'from_y': 1305.4378662109375,
#    'to_y': 1518.4378662109375},
#   'glimpse1_scale1': {'from_x': 1210.0,
#    'to_x': 1423,
#    'from_y': 1423.0,
#    'to_y': 1636.0},
#   'glimpse2_scale1': {'from_x': 1210.0,
#    'to_x': 1423,
#    'from_y': 1423.0,
#    'to_y': 1636.0},
#   'glimpse3_scale1': {'from_x': 476.4237976074219,
#    'to_x': 689.423828125,
#    'from_y': 1423.0,
#    'to_y': 1636.0}},
#  '../../attn/data/MEX/484005008/pngs/484005008_2010_all_box484005008_MAY.png': {'glimpse0_scale0': {'from_x': 794.7099609375,
#    'to_x': 1106.7099609375,
#    'from_y': 867.943115234375,
#    'to_y': 1179.943115234375},
#   'glimpse1_scale0': {'from_x': 1194.3330078125,
#    'to_x': 1506.3330078125,
#    'from_y': 1564.0,
#    'to_y': 1876.0},
#   'glimpse2_scale0': {'from_x': 1252,
#    'to_x': 1564,
#    'from_y': 1564.0,
#    'to_y': 1876.0},
#   'glimpse3_scale0': {'from_x': 1252,
#    'to_x': 1564,
#    'from_y': 1564.0,
#    'to_y': 1876.0},
#   'glimpse0_scale1': {'from_x': 794.7099609375,
#    'to_x': 1028.7099609375,
#    'from_y': 867.943115234375,
#    'to_y': 1101.943115234375},
#   'glimpse1_scale1': {'from_x': 1194.3330078125,
#    'to_x': 1428.3330078125,
#    'from_y': 1564.0,
#    'to_y': 1798.0},
#   'glimpse2_scale1': {'from_x': 1330.0,
#    'to_x': 1564,
#    'from_y': 1564.0,
#    'to_y': 1798.0},
#   'glimpse3_scale1': {'from_x': 1330.0,
#    'to_x': 1564,
#    'from_y': 1564.0,
#    'to_y': 1798.0}},
#  '../../attn/data/MEX/484001002/pngs/484001002_2010_all_box484001002_MAY.png': {'glimpse0_scale0': {'from_x': 957.6301879882812,
#    'to_x': 1215.630126953125,
#    'from_y': 1098,
#    'to_y': 1356},
#   'glimpse1_scale0': {'from_x': 1034,
#    'to_x': 1292,
#    'from_y': 1098,
#    'to_y': 1356},
#   'glimpse2_scale0': {'from_x': 1034,
#    'to_x': 1292,
#    'from_y': 803.9617309570312,
#    'to_y': 1061.961669921875},
#   'glimpse3_scale0': {'from_x': 1034,
#    'to_x': 1292,
#    'from_y': 1098,
#    'to_y': 1356},
#   'glimpse0_scale1': {'from_x': 957.6301879882812,
#    'to_x': 1151.130126953125,
#    'from_y': 1136.5767822265625,
#    'to_y': 1330.0767822265625},
#   'glimpse1_scale1': {'from_x': 1098.5,
#    'to_x': 1292,
#    'from_y': 1162.5,
#    'to_y': 1356},
#   'glimpse2_scale1': {'from_x': 1098.5,
#    'to_x': 1292,
#    'from_y': 803.9617309570312,
#    'to_y': 997.4617309570312},
#   'glimpse3_scale1': {'from_x': 1098.5,
#    'to_x': 1292,
#    'from_y': 1162.5,
#    'to_y': 1356}},
#  '../../attn/data/MEX/484004006/pngs/484004006_2010_all_box484004006_MAY.png': {'glimpse0_scale0': {'from_x': 883.599609375,
#    'to_x': 1148.599609375,
#    'from_y': 1304.9029541015625,
#    'to_y': 1569.9029541015625},
#   'glimpse1_scale0': {'from_x': 1063,
#    'to_x': 1328,
#    'from_y': 1328.0,
#    'to_y': 1593.0},
#   'glimpse2_scale0': {'from_x': 1063,
#    'to_x': 1328,
#    'from_y': 981.4060668945312,
#    'to_y': 1246.406005859375},
#   'glimpse3_scale0': {'from_x': 1063,
#    'to_x': 1328,
#    'from_y': 855.6025390625,
#    'to_y': 1120.6025390625},
#   'glimpse0_scale1': {'from_x': 883.599609375,
#    'to_x': 1082.349609375,
#    'from_y': 1304.9029541015625,
#    'to_y': 1503.6529541015625},
#   'glimpse1_scale1': {'from_x': 1129.25,
#    'to_x': 1328,
#    'from_y': 1328.0,
#    'to_y': 1526.75},
#   'glimpse2_scale1': {'from_x': 1129.25,
#    'to_x': 1328,
#    'from_y': 981.4060668945312,
#    'to_y': 1180.156005859375},
#   'glimpse3_scale1': {'from_x': 1129.25,
#    'to_x': 1328,
#    'from_y': 855.6025390625,
#    'to_y': 1054.3525390625}},
#  '../../attn/data/MEX/484001004/pngs/484001004_2010_all_box484001004_MAY.png': {'glimpse0_scale0': {'from_x': 558,
#    'to_x': 661,
#    'from_y': 416,
#    'to_y': 519},
#   'glimpse1_scale0': {'from_x': 510.2116394042969,
#    'to_x': 613.211669921875,
#    'from_y': 416,
#    'to_y': 519},
#   'glimpse2_scale0': {'from_x': 370.5018615722656,
#    'to_x': 473.5018615722656,
#    'from_y': 416,
#    'to_y': 519},
#   'glimpse3_scale0': {'from_x': 558, 'to_x': 661, 'from_y': 416, 'to_y': 519},
#   'glimpse0_scale1': {'from_x': 583.75,
#    'to_x': 661,
#    'from_y': 441.75,
#    'to_y': 519},
#   'glimpse1_scale1': {'from_x': 510.2116394042969,
#    'to_x': 587.461669921875,
#    'from_y': 441.75,
#    'to_y': 519},
#   'glimpse2_scale1': {'from_x': 370.5018615722656,
#    'to_x': 447.7518615722656,
#    'from_y': 441.75,
#    'to_y': 519},
#   'glimpse3_scale1': {'from_x': 583.75,
#    'to_x': 661,
#    'from_y': 441.75,
#    'to_y': 519}},
#  '../../attn/data/MEX/484005013/pngs/484005013_2010_all_box484005013_MAY.png': {'glimpse0_scale0': {'from_x': 1412,
#    'to_x': 1765,
#    'from_y': 1424,
#    'to_y': 1777},
#   'glimpse1_scale0': {'from_x': 1412,
#    'to_x': 1765,
#    'from_y': 1424,
#    'to_y': 1777},
#   'glimpse2_scale0': {'from_x': 1412,
#    'to_x': 1765,
#    'from_y': 1424,
#    'to_y': 1777},
#   'glimpse3_scale0': {'from_x': 1412,
#    'to_x': 1765,
#    'from_y': 1313.4957275390625,
#    'to_y': 1666.4957275390625},
#   'glimpse0_scale1': {'from_x': 1500.25,
#    'to_x': 1765,
#    'from_y': 1512.25,
#    'to_y': 1777},
#   'glimpse1_scale1': {'from_x': 1500.25,
#    'to_x': 1765,
#    'from_y': 1512.25,
#    'to_y': 1777},
#   'glimpse2_scale1': {'from_x': 1500.25,
#    'to_x': 1765,
#    'from_y': 1512.25,
#    'to_y': 1777},
#   'glimpse3_scale1': {'from_x': 1500.25,
#    'to_x': 1765,
#    'from_y': 1313.4957275390625,
#    'to_y': 1578.2457275390625}},
#  '../../attn/data/MEX/484001003/pngs/484001003_2010_all_box484001003_MAY.png': {'glimpse0_scale0': {'from_x': 1195,
#    'to_x': 1451,
#    'from_y': 1024,
#    'to_y': 1280},
#   'glimpse1_scale0': {'from_x': 1195,
#    'to_x': 1451,
#    'from_y': 1024,
#    'to_y': 1280},
#   'glimpse2_scale0': {'from_x': 1195,
#    'to_x': 1451,
#    'from_y': 1024,
#    'to_y': 1280},
#   'glimpse3_scale0': {'from_x': 1195,
#    'to_x': 1451,
#    'from_y': 1024,
#    'to_y': 1280},
#   'glimpse0_scale1': {'from_x': 1259.0,
#    'to_x': 1451,
#    'from_y': 1088.0,
#    'to_y': 1280},
#   'glimpse1_scale1': {'from_x': 1203.4931640625,
#    'to_x': 1395.4931640625,
#    'from_y': 1088.0,
#    'to_y': 1280},
#   'glimpse2_scale1': {'from_x': 1259.0,
#    'to_x': 1451,
#    'from_y': 1088.0,
#    'to_y': 1280},
#   'glimpse3_scale1': {'from_x': 1259.0,
#    'to_x': 1451,
#    'from_y': 1088.0,
#    'to_y': 1280}},
#  '../../attn/data/MEX/484005003/pngs/484005003_2010_all_box484005003_MAY.png': {'glimpse0_scale0': {'from_x': 568,
#    'to_x': 710,
#    'from_y': 710.0,
#    'to_y': 852.0},
#   'glimpse1_scale0': {'from_x': 568,
#    'to_x': 710,
#    'from_y': 533.7489013671875,
#    'to_y': 675.7489013671875},
#   'glimpse2_scale0': {'from_x': 568,
#    'to_x': 710,
#    'from_y': 593.717041015625,
#    'to_y': 735.717041015625},
#   'glimpse3_scale0': {'from_x': 568,
#    'to_x': 710,
#    'from_y': 710.0,
#    'to_y': 852.0},
#   'glimpse0_scale1': {'from_x': 603.5,
#    'to_x': 710,
#    'from_y': 710.0,
#    'to_y': 816.5},
#   'glimpse1_scale1': {'from_x': 603.5,
#    'to_x': 710,
#    'from_y': 533.7489013671875,
#    'to_y': 640.2489013671875},
#   'glimpse2_scale1': {'from_x': 603.5,
#    'to_x': 710,
#    'from_y': 593.717041015625,
#    'to_y': 700.217041015625},
#   'glimpse3_scale1': {'from_x': 603.5,
#    'to_x': 710,
#    'from_y': 710.0,
#    'to_y': 816.5}},
#  '../../attn/data/MEX/484005018/pngs/484005018_2010_all_box484005018_MAY.png': {'glimpse0_scale0': {'from_x': 1090,
#    'to_x': 1362,
#    'from_y': 1106.8408203125,
#    'to_y': 1378.8408203125},
#   'glimpse1_scale0': {'from_x': 1090,
#    'to_x': 1362,
#    'from_y': 1362.0,
#    'to_y': 1634.0},
#   'glimpse2_scale0': {'from_x': 1090,
#    'to_x': 1362,
#    'from_y': 1080.12451171875,
#    'to_y': 1352.12451171875},
#   'glimpse3_scale0': {'from_x': 857.1210327148438,
#    'to_x': 1129.12109375,
#    'from_y': 1362.0,
#    'to_y': 1634.0},
#   'glimpse0_scale1': {'from_x': 1105.4642333984375,
#    'to_x': 1309.4642333984375,
#    'from_y': 1106.8408203125,
#    'to_y': 1310.8408203125},
#   'glimpse1_scale1': {'from_x': 1158.0,
#    'to_x': 1362,
#    'from_y': 1362.0,
#    'to_y': 1566.0},
#   'glimpse2_scale1': {'from_x': 1158.0,
#    'to_x': 1362,
#    'from_y': 1080.12451171875,
#    'to_y': 1284.12451171875},
#   'glimpse3_scale1': {'from_x': 857.1210327148438,
#    'to_x': 1061.12109375,
#    'from_y': 1362.0,
#    'to_y': 1566.0}},
#  '../../attn/data/MEX/484005019/pngs/484005019_2010_all_box484005019_MAY.png': {'glimpse0_scale0': {'from_x': 635.1763916015625,
#    'to_x': 806.1763916015625,
#    'from_y': 842.152099609375,
#    'to_y': 1013.152099609375},
#   'glimpse1_scale0': {'from_x': 688,
#    'to_x': 859,
#    'from_y': 859.0,
#    'to_y': 1030.0},
#   'glimpse2_scale0': {'from_x': 688,
#    'to_x': 859,
#    'from_y': 859.0,
#    'to_y': 1030.0},
#   'glimpse3_scale0': {'from_x': 688,
#    'to_x': 859,
#    'from_y': 750.419921875,
#    'to_y': 921.419921875},
#   'glimpse0_scale1': {'from_x': 635.1763916015625,
#    'to_x': 763.4263916015625,
#    'from_y': 842.152099609375,
#    'to_y': 970.402099609375},
#   'glimpse1_scale1': {'from_x': 730.75,
#    'to_x': 859,
#    'from_y': 859.0,
#    'to_y': 987.25},
#   'glimpse2_scale1': {'from_x': 730.75,
#    'to_x': 859,
#    'from_y': 859.0,
#    'to_y': 987.25},
#   'glimpse3_scale1': {'from_x': 730.75,
#    'to_x': 859,
#    'from_y': 750.419921875,
#    'to_y': 878.669921875}},
#  '../../attn/data/MEX/484005016/pngs/484005016_2010_all_box484005016_MAY.png': {'glimpse0_scale0': {'from_x': 846,
#    'to_x': 1057,
#    'from_y': 1057.0,
#    'to_y': 1268.0},
#   'glimpse1_scale0': {'from_x': 846,
#    'to_x': 1057,
#    'from_y': 1057.0,
#    'to_y': 1268.0},
#   'glimpse2_scale0': {'from_x': 846,
#    'to_x': 1057,
#    'from_y': 830.0410766601562,
#    'to_y': 1041.041015625},
#   'glimpse3_scale0': {'from_x': 833.2044677734375,
#    'to_x': 1044.2044677734375,
#    'from_y': 1050.8074951171875,
#    'to_y': 1261.8074951171875},
#   'glimpse0_scale1': {'from_x': 898.75,
#    'to_x': 1057,
#    'from_y': 1057.0,
#    'to_y': 1215.25},
#   'glimpse1_scale1': {'from_x': 898.75,
#    'to_x': 1057,
#    'from_y': 1057.0,
#    'to_y': 1215.25},
#   'glimpse2_scale1': {'from_x': 898.75,
#    'to_x': 1057,
#    'from_y': 830.0410766601562,
#    'to_y': 988.2910766601562},
#   'glimpse3_scale1': {'from_x': 833.2044677734375,
#    'to_x': 991.4544677734375,
#    'from_y': 1050.8074951171875,
#    'to_y': 1209.0574951171875}},
#  '../../attn/data/MEX/484005015/pngs/484005015_2010_all_box484005015_MAY.png': {'glimpse0_scale0': {'from_x': 879.15576171875,
#    'to_x': 1282.15576171875,
#    'from_y': 1233.8148193359375,
#    'to_y': 1636.8148193359375},
#   'glimpse1_scale0': {'from_x': 1613,
#    'to_x': 2016,
#    'from_y': 1932.647216796875,
#    'to_y': 2335.647216796875},
#   'glimpse2_scale0': {'from_x': 1613,
#    'to_x': 2016,
#    'from_y': 2016.0,
#    'to_y': 2419.0},
#   'glimpse3_scale0': {'from_x': 1613,
#    'to_x': 2016,
#    'from_y': 1931.853271484375,
#    'to_y': 2334.853271484375},
#   'glimpse0_scale1': {'from_x': 879.15576171875,
#    'to_x': 1181.40576171875,
#    'from_y': 1233.8148193359375,
#    'to_y': 1536.0648193359375},
#   'glimpse1_scale1': {'from_x': 1713.75,
#    'to_x': 2016,
#    'from_y': 1932.647216796875,
#    'to_y': 2234.897216796875},
#   'glimpse2_scale1': {'from_x': 1713.75,
#    'to_x': 2016,
#    'from_y': 2016.0,
#    'to_y': 2318.25},
#   'glimpse3_scale1': {'from_x': 1713.75,
#    'to_x': 2016,
#    'from_y': 1931.853271484375,
#    'to_y': 2234.103271484375}},
#  '../../attn/data/MEX/484005014/pngs/484005014_2010_all_box484005014_MAY.png': {'glimpse0_scale0': {'from_x': 1660,
#    'to_x': 2074,
#    'from_y': 2031.35400390625,
#    'to_y': 2445.35400390625},
#   'glimpse1_scale0': {'from_x': 1660,
#    'to_x': 2074,
#    'from_y': 2074.0,
#    'to_y': 2488.0},
#   'glimpse2_scale0': {'from_x': 1660,
#    'to_x': 2074,
#    'from_y': 1765.7506103515625,
#    'to_y': 2179.75048828125},
#   'glimpse3_scale0': {'from_x': 1153.8831787109375,
#    'to_x': 1567.8831787109375,
#    'from_y': 1846.105224609375,
#    'to_y': 2260.105224609375},
#   'glimpse0_scale1': {'from_x': 1763.5,
#    'to_x': 2074,
#    'from_y': 2031.35400390625,
#    'to_y': 2341.85400390625},
#   'glimpse1_scale1': {'from_x': 1763.5,
#    'to_x': 2074,
#    'from_y': 2074.0,
#    'to_y': 2384.5},
#   'glimpse2_scale1': {'from_x': 1763.5,
#    'to_x': 2074,
#    'from_y': 1765.7506103515625,
#    'to_y': 2076.25048828125},
#   'glimpse3_scale1': {'from_x': 1153.8831787109375,
#    'to_x': 1464.3831787109375,
#    'from_y': 1846.105224609375,
#    'to_y': 2156.605224609375}},
#  '../../attn/data/MEX/484005017/pngs/484005017_2010_all_box484005017_MAY.png': {'glimpse0_scale0': {'from_x': 973.1472778320312,
#    'to_x': 1222.147216796875,
#    'from_y': 998,
#    'to_y': 1247},
#   'glimpse1_scale0': {'from_x': 1255,
#    'to_x': 1504,
#    'from_y': 998,
#    'to_y': 1247},
#   'glimpse2_scale0': {'from_x': 1255,
#    'to_x': 1504,
#    'from_y': 998,
#    'to_y': 1247},
#   'glimpse3_scale0': {'from_x': 1255,
#    'to_x': 1504,
#    'from_y': 998,
#    'to_y': 1247},
#   'glimpse0_scale1': {'from_x': 973.1472778320312,
#    'to_x': 1159.897216796875,
#    'from_y': 1060.25,
#    'to_y': 1247},
#   'glimpse1_scale1': {'from_x': 1317.25,
#    'to_x': 1504,
#    'from_y': 1060.25,
#    'to_y': 1247},
#   'glimpse2_scale1': {'from_x': 1317.25,
#    'to_x': 1504,
#    'from_y': 1060.25,
#    'to_y': 1247},
#   'glimpse3_scale1': {'from_x': 1317.25,
#    'to_x': 1504,
#    'from_y': 1060.25,
#    'to_y': 1247}},
#  '../../attn/data/MEX/484005021/pngs/484005021_2010_all_box484005021_MAY.png': {'glimpse0_scale0': {'from_x': 1566,
#    'to_x': 1920,
#    'from_y': 1418,
#    'to_y': 1772},
#   'glimpse1_scale0': {'from_x': 1566,
#    'to_x': 1920,
#    'from_y': 1418,
#    'to_y': 1772},
#   'glimpse2_scale0': {'from_x': 1442.1448974609375,
#    'to_x': 1796.1448974609375,
#    'from_y': 1418,
#    'to_y': 1772},
#   'glimpse3_scale0': {'from_x': 1566,
#    'to_x': 1920,
#    'from_y': 1418,
#    'to_y': 1772},
#   'glimpse0_scale1': {'from_x': 1654.5,
#    'to_x': 1920,
#    'from_y': 1506.5,
#    'to_y': 1772},
#   'glimpse1_scale1': {'from_x': 1654.5,
#    'to_x': 1920,
#    'from_y': 1506.5,
#    'to_y': 1772},
#   'glimpse2_scale1': {'from_x': 1442.1448974609375,
#    'to_x': 1707.6448974609375,
#    'from_y': 1506.5,
#    'to_y': 1772},
#   'glimpse3_scale1': {'from_x': 1654.5,
#    'to_x': 1920,
#    'from_y': 1506.5,
#    'to_y': 1772}}}

# %%
# torch.rand(2, 256).flatten(start_dim = 0).unsqueeze(0).shape

# %%
with open("sample4.json", "w") as outfile: 
    json.dump(locations_dict, outfile)

# %%
# test = torch.rand(2, 256)
# patch_dict = {}

# for patch in range(0, test.shape[0]):
#     cur_vals = list(test[patch].numpy())
#     patch_dict[patch] = [str(i) for i in cur_vals]
    
# with open("sample.json", "w") as outfile: 
#     json.dump(patch_dict, outfile)
